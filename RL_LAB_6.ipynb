# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52142/Reinforcement_Learning/blob/main/RL_LAB_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# REINFORCEMENT LEARNING - ASSIGNMENT 6
# Building a Random Agent for Reinforcement Learning Environments
# Environments: CliffWalking and Taxi

# !pip install -q gymnasium

import gymnasium as gym
import numpy as np

NUM_EPISODES = 5


def random_agent(env_name):

    print("\n" + "=" * 60)
    print("Environment:", env_name)
    print("=" * 60)

    # Create environment
    env = gym.make(env_name)

    rewards = []

    for episode in range(1, NUM_EPISODES + 1):

        # Reset environment
        state, info = env.reset()

        total_reward = 0
        steps = 0

        while True:
            # Select random action
            action = env.action_space.sample()

            # Execute action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Observe next state and reward
            state = next_state
            total_reward += reward
            steps += 1

            # Check whether episode has terminated
            if terminated or truncated:
                break

        rewards.append(total_reward)

        # Display result for each episode
        print(f"Episode {episode}: Total Reward = {total_reward}")
        print(f"Steps = {steps}")

    # Calculate average reward
    average_reward = np.mean(rewards)

    print("\nTotal Rewards:", rewards)
    print("Average Reward:", round(average_reward, 2))

    env.close()
# --------------------------------------------------
# 1. CLIFF WALKING
# --------------------------------------------------
random_agent("CliffWalking-v1")


# --------------------------------------------------
# 2. TAXI
# --------------------------------------------------
random_agent("Taxi-v4")
# Out:
# ============================================================
# Environment: CliffWalking-v1
# ============================================================
# Episode 1: Total Reward = -250519
# Steps = 25690
# Episode 2: Total Reward = -254728
# Steps = 25741
# Episode 3: Total Reward = -60793
# Steps = 6046
# Episode 4: Total Reward = -52031
# Steps = 5006
# Episode 5: Total Reward = -20785
# Steps = 2074
#
# Total Rewards: [-250519, -254728, -60793, -52031, -20785]
# Average Reward: -127771.2
#
# ============================================================
# Environment: Taxi-v4
# ============================================================
# Episode 1: Total Reward = -803
# Steps = 200
# Episode 2: Total Reward = -740
# Steps = 200
# Episode 3: Total Reward = -605
# Steps = 200
# Episode 4: Total Reward = -722
# Steps = 200
# Episode 5: Total Reward = -857
# Steps = 200
#
# Total Rewards: [-803, -740, -605, -722, -857]
# Average Reward: -745.4
